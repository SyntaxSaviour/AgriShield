# %%
import tensorflow as tf
from tensorflow.keras import layers, models
from tensorflow.keras.callbacks import EarlyStopping, ModelCheckpoint

# %%
IMG_SIZE = (224, 224)
BATCH_SIZE = 32
SEED = 42

train_dir = "../data/train"
val_dir = "../data/val"
test_dir = "../data/test"

train_ds = tf.keras.preprocessing.image_dataset_from_directory(
    train_dir,
    image_size=IMG_SIZE,
    batch_size=BATCH_SIZE,
    shuffle=True,
    seed=SEED
)

val_ds = tf.keras.preprocessing.image_dataset_from_directory(
    val_dir,
    image_size=IMG_SIZE,
    batch_size=BATCH_SIZE,
    shuffle=False
)

test_ds = tf.keras.preprocessing.image_dataset_from_directory(
    test_dir,
    image_size=IMG_SIZE,
    batch_size=BATCH_SIZE,
    shuffle=False
)

normalization_layer = layers.Rescaling(1./255)

train_ds = train_ds.map(lambda x, y: (normalization_layer(x), y))
val_ds = val_ds.map(lambda x, y: (normalization_layer(x), y))
test_ds = test_ds.map(lambda x, y: (normalization_layer(x), y))

AUTOTUNE = tf.data.AUTOTUNE
train_ds = train_ds.prefetch(AUTOTUNE)
val_ds = val_ds.prefetch(AUTOTUNE)
test_ds = test_ds.prefetch(AUTOTUNE)
# Out:
# Found 7548 files belonging to 6 classes.
# Found 1616 files belonging to 6 classes.
# Found 1623 files belonging to 6 classes.

# %%
EPOCHS = 20

early_stop = EarlyStopping(
    monitor="val_loss",
    patience=5,
    restore_best_weights=True
)

checkpoint = ModelCheckpoint(
    "../models/best_model.h5",
    monitor="val_accuracy",
    save_best_only=True,
    verbose=1
)

history = model.fit(
    train_ds,
    validation_data=val_ds,
    epochs=EPOCHS,
    callbacks=[early_stop, checkpoint]
)
# Out:
# Epoch 1/20
# 236/236 ━━━━━━━━━━━━━━━━━━━━ 0s 501ms/step - accuracy: 0.8625 - loss: 0.4161
# Epoch 1: val_accuracy improved from None to 0.91522, saving model to ../models/best_model.h5
# WARNING:absl:You are saving your model as an HDF5 file via `model.save()` or `keras.saving.save_model(model)`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')` or `keras.saving.save_model(model, 'my_model.keras')`.
# Epoch 1: finished saving model to ../models/best_model.h5
# 236/236 ━━━━━━━━━━━━━━━━━━━━ 151s 639ms/step - accuracy: 0.8735 - loss: 0.3884 - val_accuracy: 0.9152 - val_loss: 0.2801
# Epoch 2/20
# 236/236 ━━━━━━━━━━━━━━━━━━━━ 0s 503ms/step - accuracy: 0.8833 - loss: 0.3608
# Epoch 2: val_accuracy improved from 0.91522 to 0.91894, saving model to ../models/best_model.h5
# WARNING:absl:You are saving your model as an HDF5 file via `model.save()` or `keras.saving.save_model(model)`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')` or `keras.saving.save_model(model, 'my_model.keras')`.
# Epoch 2: finished saving model to ../models/best_model.h5
# 236/236 ━━━━━━━━━━━━━━━━━━━━ 145s 612ms/step - accuracy: 0.8906 - loss: 0.3347 - val_accuracy: 0.9189 - val_loss: 0.2456
# Epoch 3/20
# 236/236 ━━━━━━━━━━━━━━━━━━━━ 0s 495ms/step - accuracy: 0.8963 - loss: 0.3181
# Epoch 3: val_accuracy improved from 0.91894 to 0.92389, saving model to ../models/best_model.h5
# WARNING:absl:You are saving your model as an HDF5 file via `model.save()` or `keras.saving.save_model(model)`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')` or `keras.saving.save_model(model, 'my_model.keras')`.
# Epoch 3: finished saving model to ../models/best_model.h5
# 236/236 ━━━━━━━━━━━━━━━━━━━━ 153s 650ms/step - accuracy: 0.9050 - loss: 0.2963 - val_accuracy: 0.9239 - val_loss: 0.2263
# Epoch 4/20
# 236/236 ━━━━━━━━━━━━━━━━━━━━ 0s 524ms/step - accuracy: 0.9050 - loss: 0.2922
# Epoch 4: val_accuracy improved from 0.92389 to 0.92822, saving model to ../models/best_model.h5
# WARNING:absl:You are saving your model as an HDF5 file via `model.save()` or `keras.saving.save_model(model)`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')` or `keras.saving.save_model(model, 'my_model.keras')`.
# Epoch 4: finished saving model to ../models/best_model.h5
# 236/236 ━━━━━━━━━━━━━━━━━━━━ 148s 626ms/step - accuracy: 0.9111 - loss: 0.2707 - val_accuracy: 0.9282 - val_loss: 0.2077
# Epoch 5/20
# 236/236 ━━━━━━━━━━━━━━━━━━━━ 0s 441ms/step - accuracy: 0.9154 - loss: 0.2657
# Epoch 5: val_accuracy improved from 0.92822 to 0.93626, saving model to ../models/best_model.h5
# WARNING:absl:You are saving your model as an HDF5 file via `model.save()` or `keras.saving.save_model(model)`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')` or `keras.saving.save_model(model, 'my_model.keras')`.
# Epoch 5: finished saving model to ../models/best_model.h5
# 236/236 ━━━━━━━━━━━━━━━━━━━━ 130s 550ms/step - accuracy: 0.9245 - loss: 0.2356 - val_accuracy: 0.9363 - val_loss: 0.1940
# Epoch 6/20
# 236/236 ━━━━━━━━━━━━━━━━━━━━ 0s 487ms/step - accuracy: 0.9178 - loss: 0.2445
# Epoch 6: val_accuracy improved from 0.93626 to 0.94059, saving model to ../models/best_model.h5
# WARNING:absl:You are saving your model as an HDF5 file via `model.save()` or `keras.saving.save_model(model)`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')` or `keras.saving.save_model(model, 'my_model.keras')`.
# Epoch 6: finished saving model to ../models/best_model.h5
# 236/236 ━━━━━━━━━━━━━━━━━━━━ 147s 621ms/step - accuracy: 0.9258 - loss: 0.2185 - val_accuracy: 0.9406 - val_loss: 0.1855
# Epoch 7/20
# 236/236 ━━━━━━━━━━━━━━━━━━━━ 0s 518ms/step - accuracy: 0.9271 - loss: 0.2260
# Epoch 7: val_accuracy improved from 0.94059 to 0.94183, saving model to ../models/best_model.h5
# WARNING:absl:You are saving your model as an HDF5 file via `model.save()` or `keras.saving.save_model(model)`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')` or `keras.saving.save_model(model, 'my_model.keras')`.
# Epoch 7: finished saving model to ../models/best_model.h5
# 236/236 ━━━━━━━━━━━━━━━━━━━━ 147s 622ms/step - accuracy: 0.9307 - loss: 0.2106 - val_accuracy: 0.9418 - val_loss: 0.1770
# Epoch 8/20
# 236/236 ━━━━━━━━━━━━━━━━━━━━ 0s 470ms/step - accuracy: 0.9336 - loss: 0.2017
# Epoch 8: val_accuracy improved from 0.94183 to 0.94307, saving model to ../models/best_model.h5
# WARNING:absl:You are saving your model as an HDF5 file via `model.save()` or `keras.saving.save_model(model)`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')` or `keras.saving.save_model(model, 'my_model.keras')`.
# Epoch 8: finished saving model to ../models/best_model.h5
# 236/236 ━━━━━━━━━━━━━━━━━━━━ 134s 567ms/step - accuracy: 0.9400 - loss: 0.1877 - val_accuracy: 0.9431 - val_loss: 0.1681
# Epoch 9/20
# 236/236 ━━━━━━━━━━━━━━━━━━━━ 0s 450ms/step - accuracy: 0.9351 - loss: 0.1933
# Epoch 9: val_accuracy improved from 0.94307 to 0.94616, saving model to ../models/best_model.h5
# WARNING:absl:You are saving your model as an HDF5 file via `model.save()` or `keras.saving.save_model(model)`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')` or `keras.saving.save_model(model, 'my_model.keras')`.
# Epoch 9: finished saving model to ../models/best_model.h5
# 236/236 ━━━━━━━━━━━━━━━━━━━━ 130s 551ms/step - accuracy: 0.9438 - loss: 0.1745 - val_accuracy: 0.9462 - val_loss: 0.1637
# Epoch 10/20
# 236/236 ━━━━━━━━━━━━━━━━━━━━ 0s 440ms/step - accuracy: 0.9413 - loss: 0.1824
# Epoch 10: val_accuracy improved from 0.94616 to 0.94926, saving model to ../models/best_model.h5
# WARNING:absl:You are saving your model as an HDF5 file via `model.save()` or `keras.saving.save_model(model)`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')` or `keras.saving.save_model(model, 'my_model.keras')`.
# Epoch 10: finished saving model to ../models/best_model.h5
# 236/236 ━━━━━━━━━━━━━━━━━━━━ 127s 537ms/step - accuracy: 0.9474 - loss: 0.1633 - val_accuracy: 0.9493 - val_loss: 0.1577
# Epoch 11/20
# 236/236 ━━━━━━━━━━━━━━━━━━━━ 0s 472ms/step - accuracy: 0.9484 - loss: 0.1632
# Epoch 11: val_accuracy did not improve from 0.94926
# 236/236 ━━━━━━━━━━━━━━━━━━━━ 135s 572ms/step - accuracy: 0.9508 - loss: 0.1544 - val_accuracy: 0.9468 - val_loss: 0.1510
# Epoch 12/20
# 236/236 ━━━━━━━━━━━━━━━━━━━━ 0s 453ms/step - accuracy: 0.9516 - loss: 0.1609
# Epoch 12: val_accuracy improved from 0.94926 to 0.95050, saving model to ../models/best_model.h5
# WARNING:absl:You are saving your model as an HDF5 file via `model.save()` or `keras.saving.save_model(model)`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')` or `keras.saving.save_model(model, 'my_model.keras')`.
# Epoch 12: finished saving model to ../models/best_model.h5
# 236/236 ━━━━━━━━━━━━━━━━━━━━ 129s 548ms/step - accuracy: 0.9544 - loss: 0.1462 - val_accuracy: 0.9505 - val_loss: 0.1473
# Epoch 13/20
# 236/236 ━━━━━━━━━━━━━━━━━━━━ 0s 443ms/step - accuracy: 0.9530 - loss: 0.1546
# Epoch 13: val_accuracy did not improve from 0.95050
# 236/236 ━━━━━━━━━━━━━━━━━━━━ 138s 586ms/step - accuracy: 0.9565 - loss: 0.1405 - val_accuracy: 0.9486 - val_loss: 0.1443
# Epoch 14/20
# 236/236 ━━━━━━━━━━━━━━━━━━━━ 0s 437ms/step - accuracy: 0.9570 - loss: 0.1426
# Epoch 14: val_accuracy did not improve from 0.95050
# 236/236 ━━━━━━━━━━━━━━━━━━━━ 125s 528ms/step - accuracy: 0.9607 - loss: 0.1295 - val_accuracy: 0.9505 - val_loss: 0.1381
# Epoch 15/20
# 236/236 ━━━━━━━━━━━━━━━━━━━━ 0s 439ms/step - accuracy: 0.9573 - loss: 0.1336
# Epoch 15: val_accuracy improved from 0.95050 to 0.95235, saving model to ../models/best_model.h5
# WARNING:absl:You are saving your model as an HDF5 file via `model.save()` or `keras.saving.save_model(model)`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')` or `keras.saving.save_model(model, 'my_model.keras')`.
# Epoch 15: finished saving model to ../models/best_model.h5
# 236/236 ━━━━━━━━━━━━━━━━━━━━ 126s 535ms/step - accuracy: 0.9605 - loss: 0.1222 - val_accuracy: 0.9524 - val_loss: 0.1343
# Epoch 16/20
# 236/236 ━━━━━━━━━━━━━━━━━━━━ 0s 434ms/step - accuracy: 0.9603 - loss: 0.1275
# Epoch 16: val_accuracy did not improve from 0.95235
# 236/236 ━━━━━━━━━━━━━━━━━━━━ 125s 528ms/step - accuracy: 0.9632 - loss: 0.1165 - val_accuracy: 0.9517 - val_loss: 0.1327
# Epoch 17/20
# 236/236 ━━━━━━━━━━━━━━━━━━━━ 0s 438ms/step - accuracy: 0.9623 - loss: 0.1217
# Epoch 17: val_accuracy did not improve from 0.95235
# 236/236 ━━━━━━━━━━━━━━━━━━━━ 125s 529ms/step - accuracy: 0.9657 - loss: 0.1096 - val_accuracy: 0.9517 - val_loss: 0.1278
# Epoch 18/20
# 236/236 ━━━━━━━━━━━━━━━━━━━━ 0s 439ms/step - accuracy: 0.9654 - loss: 0.1187
# Epoch 18: val_accuracy did not improve from 0.95235
# 236/236 ━━━━━━━━━━━━━━━━━━━━ 126s 533ms/step - accuracy: 0.9681 - loss: 0.1081 - val_accuracy: 0.9517 - val_loss: 0.1280
# Epoch 19/20
# 236/236 ━━━━━━━━━━━━━━━━━━━━ 0s 436ms/step - accuracy: 0.9634 - loss: 0.1149
# Epoch 19: val_accuracy improved from 0.95235 to 0.95359, saving model to ../models/best_model.h5
# WARNING:absl:You are saving your model as an HDF5 file via `model.save()` or `keras.saving.save_model(model)`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')` or `keras.saving.save_model(model, 'my_model.keras')`.
# Epoch 19: finished saving model to ../models/best_model.h5
# 236/236 ━━━━━━━━━━━━━━━━━━━━ 127s 536ms/step - accuracy: 0.9683 - loss: 0.1027 - val_accuracy: 0.9536 - val_loss: 0.1254
# Epoch 20/20
# 236/236 ━━━━━━━━━━━━━━━━━━━━ 0s 434ms/step - accuracy: 0.9653 - loss: 0.1019
# Epoch 20: val_accuracy improved from 0.95359 to 0.95421, saving model to ../models/best_model.h5
# WARNING:absl:You are saving your model as an HDF5 file via `model.save()` or `keras.saving.save_model(model)`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')` or `keras.saving.save_model(model, 'my_model.keras')`.
# Epoch 20: finished saving model to ../models/best_model.h5
# 236/236 ━━━━━━━━━━━━━━━━━━━━ 126s 534ms/step - accuracy: 0.9705 - loss: 0.0938 - val_accuracy: 0.9542 - val_loss: 0.1241
